# %% [markdown]
# # 🤗 x 🦾: Training SmolVLA with LeRobot Notebook
#
# Welcome to the **LeRobot SmolVLA training notebook**! This notebook provides a ready-to-run setup for training imitation learning policies using the [🤗 LeRobot](https://github.com/huggingface/lerobot) library.
#
# In this example, we train an `SmolVLA` policy using a dataset hosted on the [Hugging Face Hub](https://huggingface.co/), and optionally track training metrics with [Weights & Biases (wandb)](https://wandb.ai/).
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=YOUR_USERNAME/YOUR_DATASET`)
# - Optional: A [wandb](https://wandb.ai/) account if you want to enable training visualization
# - Recommended: GPU runtime (e.g., NVIDIA A100) for faster training
#
# ## ⏱️ Expected Training Time
# Training with the `SmolVLA` policy for 20,000 steps typically takes **about 5 hours on an NVIDIA A100** GPU. On less powerful GPUs or CPUs, training may take significantly longer!
#
# ## Example Output
# Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`. If `wandb` is enabled, progress will also be visualized in your wandb project dashboard.

# %% [markdown]
# ## Install conda
# This cell uses `condacolab` to bootstrap a full Conda environment inside Google Colab.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# ## Install LeRobot
# This cell clones the `lerobot` repository from Hugging Face, installs FFmpeg (version 7.1.1), and installs the package in editable mode.

# %%
# !git clone https://github.com/adam-malyshev/lerobot-audio.git
# !conda install ffmpeg=7.1.1 -c conda-forge
# !cd lerobot-audio && git checkout fix/audio_recording && pip install -e .
# Out:
# fatal: destination path 'lerobot-audio' already exists and is not an empty directory.
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# Already on 'fix/audio_recording'
# Your branch is up to date with 'origin/fix/audio_recording'.
# Obtaining file:///content/lerobot-audio
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets<4.2.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.1.1)
# Requirement already satisfied: diffusers<0.36.0,>=0.27.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.35.2)
# Requirement already satisfied: huggingface-hub<0.36.0,>=0.34.2 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.35.3)
# Requirement already satisfied: accelerate<2.0.0,>=1.10.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (1.12.0)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (80.9.0)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.1.3)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.8.1)
# Requirement already satisfied: opencv-python-headless<4.13.0,>=4.9.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.12.0.88)
# Requirement already satisfied: av<16.0.0,>=15.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (15.1.0)
# Requirement already satisfied: jsonlines<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.0.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (24.2)
# Requirement already satisfied: pynput<1.9.0,>=1.7.7 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (1.8.1)
# Requirement already satisfied: pyserial<4.0,>=3.5 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (3.5)
# Requirement already satisfied: wandb<0.22.0,>=0.20.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.21.4)
# Requirement already satisfied: torch<2.8.0,>=2.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (2.7.1)
# Requirement already satisfied: torchcodec<0.6.0,>=0.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.5)
# Requirement already satisfied: torchvision<0.23.0,>=0.21.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.22.1)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.10.0)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (1.2.2)
# Requirement already satisfied: rerun-sdk<0.27.0,>=0.24.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.26.2)
# Requirement already satisfied: deepdiff<9.0.0,>=7.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (8.6.1)
# Requirement already satisfied: imageio<3.0.0,>=2.34.0 in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1) (2.37.2)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (3.2.0)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1) (2.2.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1) (7.1.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.20.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.9.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.11/site-packages (from deepdiff<9.0.0,>=7.0.1->lerobot==0.4.1) (5.5.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (8.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (2025.11.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (12.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (0.0.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/site-packages (from huggingface-hub<0.36.0,>=0.34.2->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (1.2.0)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.3.4)
# Requirement already satisfied: hf-transfer>=0.1.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.1.9)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (3.0.52)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1) (0.6.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/site-packages (from jsonlines<5.0.0,>=4.0.0->lerobot==0.4.1) (25.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (1.9.2)
# Requirement already satisfied: python-xlib>=0.17 in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (0.33)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.3.1)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (6.33.2)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.12.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.47.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.13.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/site-packages (from sympy>=1.13.3->torch<2.8.0,>=2.2.1->lerobot==0.4.1) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.4.1) (1.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/site-packages (from importlib_metadata->diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (5.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.2.14)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.4.1-0.editable-py3-none-any.whl size=15716 sha256=870c082cdb73c17b10d08424d67ee82a15e82f28dbf4a1c87f4e295bb855b43c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-neilats8/wheels/23/19/08/33520190e19bcc224c03c0475939567485e3318da98015612b
# Successfully built lerobot
# Installing collected packages: lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.4.1
#     Uninstalling lerobot-0.4.1:
#       Successfully uninstalled lerobot-0.4.1
# Successfully installed lerobot-0.4.1

# %% [markdown]
# ## Weights & Biases login
# This cell logs you into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !wandb login
# Out:
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: Currently logged in as: adam-malyshev (adam-malyshev-university-of-maryland) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## Install SmolVLA dependencies

# %%
# !cd lerobot-audio && pip install -e ".[smolvla, audio]"
# Out:
# Obtaining file:///content/lerobot-audio
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets<4.2.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.1.1)
# Requirement already satisfied: diffusers<0.36.0,>=0.27.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.35.2)
# Requirement already satisfied: huggingface-hub<0.36.0,>=0.34.2 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.35.3)
# Requirement already satisfied: accelerate<2.0.0,>=1.10.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (1.12.0)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (80.9.0)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.1.3)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.8.1)
# Requirement already satisfied: opencv-python-headless<4.13.0,>=4.9.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.12.0.88)
# Requirement already satisfied: av<16.0.0,>=15.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (15.1.0)
# Requirement already satisfied: jsonlines<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.0.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (24.2)
# Requirement already satisfied: pynput<1.9.0,>=1.7.7 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (1.8.1)
# Requirement already satisfied: pyserial<4.0,>=3.5 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (3.5)
# Requirement already satisfied: wandb<0.22.0,>=0.20.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.21.4)
# Requirement already satisfied: torch<2.8.0,>=2.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (2.7.1)
# Requirement already satisfied: torchcodec<0.6.0,>=0.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.5)
# Requirement already satisfied: torchvision<0.23.0,>=0.21.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.22.1)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.10.0)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (1.2.2)
# Requirement already satisfied: rerun-sdk<0.27.0,>=0.24.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.26.2)
# Requirement already satisfied: deepdiff<9.0.0,>=7.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (8.6.1)
# Requirement already satisfied: imageio<3.0.0,>=2.34.0 in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1) (2.37.2)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (3.2.0)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (0.9.0)
# Requirement already satisfied: num2words<0.6.0,>=0.5.14 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.5.14)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.3 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.7.0)
# Requirement already satisfied: sounddevice<0.6.0,>=0.5.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.5.3)
# Requirement already satisfied: soundfile<0.14.0,>=0.13.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.13.1)
# Requirement already satisfied: librosa<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.11.0)
# Requirement already satisfied: torchaudio<2.10.0,>=2.6.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (2.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1) (2.2.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1) (7.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.20.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.9.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.11/site-packages (from deepdiff<9.0.0,>=7.0.1->lerobot==0.4.1) (5.5.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (8.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (2025.11.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (12.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (0.0.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/site-packages (from huggingface-hub<0.36.0,>=0.34.2->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (1.2.0)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.3.4)
# Requirement already satisfied: hf-transfer>=0.1.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.1.9)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (3.0.52)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1) (0.6.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/site-packages (from jsonlines<5.0.0,>=4.0.0->lerobot==0.4.1) (25.4.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/site-packages (from librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/site-packages (from librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (0.63.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/site-packages (from librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/site-packages (from librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (1.8.0)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/site-packages (from librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/site-packages (from librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/site-packages (from librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/site-packages (from librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/site-packages (from librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/site-packages (from librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (1.1.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.11/site-packages (from num2words<0.6.0,>=0.5.14->lerobot==0.4.1) (0.6.2)
# Requirement already satisfied: six in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (1.9.2)
# Requirement already satisfied: python-xlib>=0.17 in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (0.33)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/site-packages (from sounddevice<0.6.0,>=0.5.1->lerobot==0.4.1) (1.17.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.3.1)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (6.33.2)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.12.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.47.0)
# Requirement already satisfied: transformers<5.0.0,>=4.53.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.57.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/site-packages (from CFFI>=1.0->sounddevice<0.6.0,>=0.5.1->lerobot==0.4.1) (2.22)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.13.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (4.0.12)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /usr/local/lib/python3.11/site-packages (from numba>=0.51.0->librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (0.46.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.11.12)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.11/site-packages (from scikit-learn>=1.1.0->librosa<0.12.0,>=0.11.0->lerobot==0.4.1) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/site-packages (from sympy>=1.13.3->torch<2.8.0,>=2.2.1->lerobot==0.4.1) (1.3.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.11/site-packages (from transformers<5.0.0,>=4.53.0->lerobot==0.4.1) (0.22.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.4.1) (1.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/site-packages (from importlib_metadata->diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (5.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.2.14)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.4.1-0.editable-py3-none-any.whl size=15716 sha256=cb8a3c85e759e21912806ceee0d91c989b20b4335ee600705e45a095dd1295fd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1kisrgr1/wheels/23/19/08/33520190e19bcc224c03c0475939567485e3318da98015612b
# Successfully built lerobot
# Installing collected packages: lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.4.1
#     Uninstalling lerobot-0.4.1:
#       Successfully uninstalled lerobot-0.4.1
# Successfully installed lerobot-0.4.1

# %% [markdown]
# ## Login into Hugging Face Hub
# Now after training is done login into the Hugging Face hub and upload the last checkpoint

# %%
# !hf auth login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n)
# Token is valid (permission: read).
# The token `mac_token` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `mac_token`

# %% [markdown]
# ## Start training SmolVLA with LeRobot
#
# This cell runs the `train.py` script from the `lerobot` library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `pepijn223/il_gym0`.
#
# 2. `--batch_size=64`: means the model processes 64 training samples in parallel before doing one gradient update. Reduce this number if you have a GPU with low memory.
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an NVIDIA GPU. Use `mps` for Apple Silicon, or `cpu` if no GPU is available.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this.

# %%
# !cd lerobot-audio && src/lerobot/scripts/train_audio \
  --policy.type=audiosmolvla \
  --base_policy-path=lerobot/smolvla_base \
  --policy.repo_id=AdamMalyshev/audiosmolvla \
  --dataset.repo_id=AdamMalyshev/bell_ring_put_tape_in_bin \
  --batch_size=64 \
  --steps=20000 \
  --save_freq=1000 \
  --output_dir=outputs/train/audiosmolvla \
  --job_name=audiosmolvla_training \
  --policy.device=cuda \
  --wandb.enable=true
# Out:
# INFO 2025-12-13 20:09:56 ot_train.py:163 {'batch_size': 64,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'AdamMalyshev/bell_ring_put_tape_in_bin',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'audiosmolvla_training',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.95],
#                'eps': 1e-08,
#                'grad_clip_norm': 10,
#                'lr': 0.0001,
#                'type': 'adamw',
#                'weight_decay': 1e-10},
#  'output_dir': 'outputs/train/audiosmolvla',
#  'policy': {'adapt_to_pi_aloha': False,
#             'add_audio_special_tokens': False,
#             'add_image_special_tokens': False,
#             'attention_mode': 'cross_attn',
#             'audio_model_name': 'dymn10_as',
#             'audio_projector_repo_id': 'shivamg05/SmolVLA-Audio-Projector',
#             'audio_token_dim': 960,
#             'chunk_size': 50,
#             'device': 'cuda',
#             'empty_cameras': 0,
#             'expert_width_multiplier': 0.75,
#             'freeze_vision_encoder': True,
#             'input_features': {},
#             'license': None,
#             'load_vlm_weights': False,
#             'max_action_dim': 32,
#             'max_period': 4.0,
#             'max_state_dim': 32,
#             'min_period': 0.004,
#             'n_action_steps': 50,
#             'n_obs_steps': 1,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.IDENTITY: 'IDENTITY'>},
#             'num_expert_layers': -1,
#             'num_steps': 10,
#             'num_vlm_layers': 16,
#             'optimizer_betas': [0.9, 0.95],
#             'optimizer_eps': 1e-08,
#             'optimizer_grad_clip_norm': 10,
#             'optimizer_lr': 0.0001,
#             'optimizer_weight_decay': 1e-10,
#             'output_features': {},
#             'pad_language_to': 'longest',
#             'prefix_length': -1,
#             'pretrained_path': 'lerobot/smolvla_base',
#             'private': None,
#             'push_to_hub': True,
#             'repo_id': 'AdamMalyshev/audiosmolvla',
#             'resize_imgs_with_padding': [512, 512],
#             'sampling_rate': 32000,
#             'scheduler_decay_lr': 2.5e-06,
#             'scheduler_decay_steps': 30000,
#             'scheduler_warmup_steps': 1000,
#             'self_attn_every_n_layers': 2,
#             'tags': None,
#             'target_audio_len_samples': 320000,
#             'tokenizer_max_length': 48,
#             'train_expert_only': True,
#             'train_state_proj': True,
#             'type': 'audiosmolvla',
#             'use_amp': False,
#             'use_cache': True,
#             'use_delta_joint_actions_aloha': False,
#             'vlm_model_name': 'shivamg05/SmolVLM2-500M-Audio-Aligned'},
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 1000,
#  'scheduler': {'decay_lr': 2.5e-06,
#                'num_decay_steps': 30000,
#                'num_warmup_steps': 1000,
#                'peak_lr': 0.0001,
#                'type': 'cosine_decay_with_warmup'},
#  'seed': 1000,
#  'steps': 20000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO 2025-12-13 20:09:58 db_utils.py:102 Logs will be synced with wandb.
# INFO 2025-12-13 20:09:58 db_utils.py:103 Track this run --> https://wandb.ai/adam-malyshev-university-of-maryland/lerobot/runs/nb8wgenz
# INFO 2025-12-13 20:09:58 ot_train.py:183 Creating dataset
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# meta/episodes/chunk-000/file-000.parquet:   0% 0.00/258k [00:00<?, ?B/s]
#
# meta/tasks.parquet:   0% 0.00/2.34k [00:00<?, ?B/s]
#
#
# stats.json: 13.9kB [00:00, 18.1MB/s]
#
#
#
# info.json: 3.84kB [00:00, 3.59MB/s]
#
#
# meta/tasks.parquet: 100% 2.34k/2.34k [00:01<00:00, 2.01kB/s]
# meta/tasks.parquet: 100% 2.34k/2.34k [00:01<00:00, 2.01kB/s]
# meta/episodes/chunk-000/file-000.parquet: 100% 258k/258k [00:01<00:00, 215kB/s]
# Fetching 4 files: 100% 4/4 [00:01<00:00,  2.74it/s]
# Fetching 10 files:   0% 0/10 [00:00<?, ?it/s]
# data/chunk-000/file-000.parquet:   0% 0.00/1.01M [00:00<?, ?B/s]
#
# videos/observation.images.front/chunk-00(…):   0% 0.00/296M [00:00<?, ?B/s]
#
#
# videos/observation.images.top/chunk-000/(…):   0% 0.00/410M [00:00<?, ?B/s]
#
#
#
# audio/observation.audio.mic_front/chunk-(…):   0% 0.00/19.5M [00:00<?, ?B/s]
#
#
#
#
# README.md: 4.33kB [00:00, 7.23MB/s]
#
#
#
#
#
# .gitattributes: 2.55kB [00:00, 5.76MB/s]
# Fetching 10 files:  10% 1/10 [00:00<00:04,  1.84it/s]
# data/chunk-000/file-000.parquet: 100% 1.01M/1.01M [00:00<00:00, 2.69MB/s]
#
#
#
# videos/observation.images.top/chunk-000/(…):   2% 7.41M/410M [00:01<01:35, 4.23MB/s]
#
# videos/observation.images.front/chunk-00(…):   9% 27.9M/296M [00:02<00:19, 13.8MB/s]
#
#
#
# audio/observation.audio.mic_front/chunk-(…): 100% 19.5M/19.5M [00:02<00:00, 8.99MB/s]
# Fetching 10 files:  30% 3/10 [00:02<00:06,  1.14it/s]
#
# videos/observation.images.front/chunk-00(…):  32% 95.0M/296M [00:03<00:05, 35.2MB/s]
#
#
# videos/observation.images.top/chunk-000/(…):  18% 74.4M/410M [00:03<00:12, 26.1MB/s]
#
# videos/observation.images.front/chunk-00(…): 100% 296M/296M [00:03<00:00, 86.2MB/s]
# Fetching 10 files:  90% 9/10 [00:03<00:00,  2.77it/s]
#
#
# videos/observation.images.top/chunk-000/(…):  67% 276M/410M [00:03<00:01, 123MB/s]
#
#
# videos/observation.images.top/chunk-000/(…): 100% 410M/410M [00:04<00:00, 94.2MB/s]
# Fetching 10 files: 100% 10/10 [00:04<00:00,  2.13it/s]
# INFO 2025-12-13 20:10:05 ot_train.py:202 Creating policy
# config.json: 4.20kB [00:00, 5.56MB/s]
# processor_config.json: 100% 67.0/67.0 [00:00<00:00, 223kB/s]
# chat_template.jinja: 100% 403/403 [00:00<00:00, 1.51MB/s]
# preprocessor_config.json: 100% 599/599 [00:00<00:00, 2.11MB/s]
# tokenizer_config.json: 28.2kB [00:00, 34.9MB/s]
# vocab.json: 801kB [00:00, 5.79MB/s]
# merges.txt: 466kB [00:00, 5.37MB/s]
# tokenizer.json: 3.55MB [00:00, 19.5MB/s]
# added_tokens.json: 4.74kB [00:00, 7.23MB/s]
# special_tokens_map.json: 100% 868/868 [00:00<00:00, 4.32MB/s]
# video_preprocessor_config.json: 100% 944/944 [00:00<00:00, 4.53MB/s]
# Reducing the number of VLM layers to 16 ...
# Failed to load audio projector weights from shivamg05/SmolVLA-Audio-Projector: 404 Client Error. (Request ID: Root=1-693dc837-41e1a73e79d29ec63fa1047a;5c848873-de0e-433f-8d3f-421c859aafa1)
#
# Entry Not Found for url: https://huggingface.co/shivamg05/SmolVLA-Audio-Projector/resolve/main/pytorch_model.bin.
# Using random initialization for audio projector
# /usr/local/lib/python3.11/site-packages/torchvision/ops/misc.py:120: UserWarning: Don't use ConvNormActivation directly, please use Conv2dNormActivation and Conv3dNormActivation instead.
#   warnings.warn(
# Loaded pretrained weights for dymn10_as
# model.safetensors: 100% 907M/907M [00:01<00:00, 542MB/s]
# WARNING 2025-12-13 20:10:34 ies/utils.py:91 Missing key(s) when loading model: {'model.audio_encoder.model.classifier.2.bias', 'model.audio_encoder.model.layers.1.depth_act.init_v', 'model.audio_encoder.model.layers.8.context_gen.conv_t.bias', 'model.audio_encoder.model.layers.4.exp_conv.weight', 'model.audio_encoder.model.layers.11.context_gen.joint_norm.weight', 'model.audio_encoder.model.layers.8.exp_norm.bias', 'model.audio_encoder.model.layers.7.depth_norm.running_var', 'model.audio_encoder.model.layers.2.proj_norm.bias', 'model.audio_encoder.model.layers.12.depth_norm.bias', 'model.audio_encoder.model.layers.14.proj_conv.residuals.0.bias', 'model.audio_encoder.model.layers.8.proj_norm.weight', 'model.audio_encoder.model.layers.3.depth_conv.residuals.0.bias', 'model.audio_encoder.model.layers.14.exp_norm.weight', 'model.audio_encoder.model.layers.5.proj_norm.running_mean', 'model.audio_encoder.model.layers.2.context_gen.conv_t.bias', 'model.audio_encoder.model.layers.3.context_gen.joint_norm.bias', 'model.audio_encoder.model.layers.6.depth_norm.running_mean', 'model.audio_encoder.model.layers.13.context_gen.conv_t.bias', 'model.audio_encoder.model.layers.1.proj_conv.residuals.0.weight', 'model.audio_encoder.model.layers.7.context_gen.joint_norm.running_var', 'model.audio_encoder.model.layers.1.context_gen.conv_t.weight', 'model.audio_encoder.model.layers.5.context_gen.joint_norm.running_mean', 'model.audio_encoder.model.out_c.0.weight', 'model.audio_encoder.model.classifier.5.bias', 'model.audio_encoder.model.layers.12.proj_conv.residuals.0.bias', 'model.audio_encoder.model.layers.13.proj_conv.residuals.0.bias', 'model.audio_encoder.model.layers.13.proj_norm.bias', 'model.audio_encoder.model.layers.1.proj_norm.running_var', 'model.audio_encoder.model.layers.10.depth_act.coef_net.0.weight', 'model.audio_encoder.model.layers.5.context_gen.conv_t.bias', 'model.audio_encoder.model.layers.8.depth_act.coef_net.0.weight', 'model.audio_encoder.model.layers.7.proj_norm.bias', 'model.audio_encoder.model.layers.6.proj_norm.running_var', 'model.audio_encoder.model.layers.8.depth_norm.running_var', 'model.audio_encoder.model.layers.7.depth_act.coef_net.0.bias', 'model.audio_encoder.model.layers.8.proj_conv.weight', 'model.audio_encoder.model.layers.0.context_gen.joint_norm.weight', 'model.audio_encoder.model.layers.2.depth_conv.residuals.0.weight', 'model.audio_encoder.model.layers.13.proj_conv.weight', 'model.audio_encoder.model.layers.8.proj_conv.residuals.0.bias', 'model.audio_encoder.model.layers.5.exp_conv.residuals.0.weight', 'model.audio_encoder.model.layers.3.depth_conv.residuals.0.weight', 'model.audio_encoder.model.layers.5.depth_act.coef_net.0.weight', 'model.audio_encoder.model.layers.8.depth_act.lambdas', 'model.audio_encoder.model.layers.2.context_gen.joint_norm.running_var', 'model.audio_encoder.model.layers.10.depth_act.coef_net.0.bias', 'model.audio_encoder.model.layers.12.context_gen.conv_f.weight', 'model.audio_encoder.model.layers.4.exp_norm.bias', 'model.audio_encoder.model.layers.14.depth_norm.weight', 'model.audio_encoder.model.layers.4.proj_conv.residuals.0.weight', 'model.audio_encoder.model.layers.14.depth_act.coef_net.0.weight', 'model.audio_encoder.model.layers.6.depth_act.init_v', 'model.audio_encoder.model.layers.4.exp_norm.running_var', 'model.audio_encoder.model.layers.6.context_gen.conv_f.weight', 'model.audio_encoder.model.layers.11.depth_conv.residuals.0.bias', 'model.audio_encoder.model.layers.12.proj_norm.running_mean', 'model.audio_encoder.model.layers.13.exp_norm.running_mean', 'model.audio_encoder.model.layers.1.context_gen.conv_t.bias', 'model.audio_encoder.model.layers.3.depth_act.init_v', 'model.audio_encoder.model.layers.4.context_gen.joint_norm.running_var', 'model.audio_encoder.model.layers.2.depth_norm.running_mean', 'model.audio_encoder.model.layers.6.depth_act.lambdas', 'model.audio_encoder.model.layers.5.context_gen.joint_conv.weight', 'model.audio_encoder.model.layers.12.context_gen.c ...
# policy_preprocessor.json: 1.87kB [00:00, 3.02MB/s]
# tokenizer_config.json: 28.6kB [00:00, 40.2MB/s]
# vocab.json: 801kB [00:00, 5.47MB/s]
# merges.txt: 466kB [00:00, 5.16MB/s]
# tokenizer.json: 3.55MB [00:00, 15.5MB/s]
# added_tokens.json: 4.74kB [00:00, 7.39MB/s]
# special_tokens_map.json: 100% 868/868 [00:00<00:00, 4.38MB/s]
# policy_preprocessor_step_5_normalizer_pr(…): 100% 640/640 [00:00<00:00, 2.82kB/s]
# policy_postprocessor.json: 100% 660/660 [00:00<00:00, 3.03MB/s]
# INFO 2025-12-13 20:10:40 ot_train.py:247 Creating optimizer and scheduler
# INFO 2025-12-13 20:10:40 hedulers.py:105 Auto-scaling LR scheduler: num_training_steps (20000) < num_decay_steps (30000). Scaling warmup: 1000 → 666, decay: 30000 → 20000 (scale factor: 0.667)
# INFO 2025-12-13 20:10:40 ot_train.py:259 Output dir: outputs/train/audiosmolvla
# INFO 2025-12-13 20:10:40 ot_train.py:262 cfg.steps=20000 (20K)
# INFO 2025-12-13 20:10:40 ot_train.py:263 dataset.num_frames=30598 (31K)
# INFO 2025-12-13 20:10:40 ot_train.py:264 dataset.num_episodes=50
# INFO 2025-12-13 20:10:40 ot_train.py:267 Effective batch size: 64 x 1 = 64
# INFO 2025-12-13 20:10:40 ot_train.py:268 num_learnable_params=101726112 (102M)
# INFO 2025-12-13 20:10:40 ot_train.py:269 num_total_params=462439775 (462M)
# INFO 2025-12-13 20:10:40 ot_train.py:324 Start offline training on a fixed dataset
# Traceback (most recent call last):
#   File "/usr/local/bin/lerobot-train", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/content/lerobot-audio/src/lerobot/scripts/lerobot_train.py", line 444, in main
#     train()
#   File "/content/lerobot-audio/src/lerobot/configs/parser.py", line 233, in wrapper_inner
#     response = fn(cfg, *args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lerobot-audio/src/lerobot/scripts/lerobot_train.py", line 332, in train
#     train_tracker, output_dict = update_policy(
#                                  ^^^^^^^^^^^^^^
#   File "/content/lerobot-audio/src/lerobot/scripts/lerobot_train.py", line 91, in update_policy
#     loss, output_dict = policy.forward(batch)
#                         ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lerobot-audio/src/lerobot/policies/audiosmolvla/modeling_audiosmolvla.py", line 148, in forward
#     losses = self.model.forward(
#              ^^^^^^^^^^^^^^^^^^^
#   File "/content/lerobot-audio/src/lerobot/policies/audiosmolvla/modeling_audiosmolvla.py", line 426, in forward
#     prefix_embs, prefix_pad_masks, prefix_att_masks = self.embed_prefix(
#                                                       ^^^^^^^^^^^^^^^^^^
#   File "/content/lerobot-audio/src/lerobot/policies/audiosmolvla/modeling_audiosmolvla.py", line 335, in embed_prefix
#     audio_emb = self.embed_audio(audio)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lerobot-audio/src/lerobot/policies/audiosmolvla/modeling_audiosmolvla.py", line 247, in embed_audio
#     features = self.audio_encoder(audio_spectrogram)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lerobot-audio/src/lerobot/policies/audiosmolvla/dymn.py", line 661, in forward
#     _, embeddings = self.model(spec)
#                     ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lerobot-audio/src/lerobot/policies/audiosmolvla/dymn.py", line 493, in forward
#     x = self._feature_forward(x)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lerobot-audio/src/lerobot/policies/audiosmolvla/dymn.py", line 470, in _feature_forward
#     x = self.in_c(x)
#         ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/nn/modules/container.py", line 240, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/nn/modules/conv.py", line 554, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/torch/nn/modules/conv.py", line 549, in _conv_forward
#     return F.conv2d(
#            ^^^^^^^^^
# RuntimeError: Given groups=1, weight of size [16, 1, 3, 3], expected input[1, 64, 1, 22050] to have 1 channels, but got 64 channels instead
